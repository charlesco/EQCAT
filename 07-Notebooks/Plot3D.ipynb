# %%
# %matplotlib inline
import numpy as np
from EQCAT.parse_files import parse_quakes
seismes=parse_quakes()
# Out:
# ('Total quakes : ', 37224)

# %%
q=seismes["F016021"]
q.shape.plot3d()

# %%
q=seismes["ATHOP"]
q.shape.plot3d()

# %%
q=seismes["CPCF_INTRA_13_5633"]
for domain in q.dom_dict.values():
    domain.plot3d()
    break
